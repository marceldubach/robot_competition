# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# ### Read csv file

# %%
log = pd.read_csv("logs/obstacles_01-06-2021_20-56-35.csv")

# %%
log
# Out:
#     Unnamed: 0         x         y
# 0            0  2.748117  0.534485
# 1            1  5.688652  4.097308
# 2            2  4.161378  4.162067
# 3            3  4.360070  4.660043
# 4            4  4.198126  2.801606
# 5            5  4.036474  3.373852
# 6            6  3.412636  3.594904
# 7            7  2.280126  1.363719
# 8            8  1.934051  1.845139
# 9            9  1.968421  1.034721
# 10          10  1.431905  1.887628
# 11          11  1.057705  2.213585
# 12          12  2.008920  1.499809
# 13          13  1.688845  1.671398
# 14          14  1.344664  2.332314
# 15          15  0.823762  2.634842
# 16          16  0.555705  3.028167
# 17          17  0.248867  2.879049
# 18          18  2.311844  3.052373
# 19          19  1.707873  3.470003
# 20          20  1.937219  3.065876
# 21          21  1.706516  2.420313
# 22          22  1.459600  2.734141
# 23          23  2.206399  1.971566
# 24          24  1.696184  2.102529
# 25          25  1.378931  1.577549
# ...

# %% [markdown]
# ### Create plot

# %%
plt.figure()
plt.plot('x','y','ro',data=log)
plt.axis([0, 8, 0, 8])
# Out:
# [0, 8, 0, 8]
