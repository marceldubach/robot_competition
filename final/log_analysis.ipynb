# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# ### Read csv file

# %%
log = pd.read_csv("logs/obstacles_01-07-2021_15-51-27.csv")

# %%
log
# Out:
#     Unnamed: 0         x         y
# 0            0  2.990104  1.414346
# 1            1  4.553053  1.207278
# 2            2  4.493258  1.416390
# 3            3  5.252839  1.147673
# 4            4  5.101326  0.872087
# 5            5  5.147638  0.727339
# 6            6  5.898968  2.074800
# 7            7  6.568575  2.223555
# 8            8  6.455345  2.346392
# 9            9  7.069763  1.130011
# 10          10  6.680975  2.323101
# 11          11  6.076313  2.281575
# 12          12  2.186240  2.301841
# 13          13  1.880815  2.793811
# 14          14  1.758223  2.961097
# 15          15  2.101251  2.430956
# 16          16  1.787090  2.290919
# 17          17  2.009535  2.561933
# 18          18  2.351939  2.127837
# 19          19  1.641556  2.748308
# 20          20  3.958020  3.555372
# 21          21  3.859709  3.695657
# 22          22  4.190799  4.469339
# 23          23  4.955977  5.218246
# 24          24  5.114152  5.116144
# 25          25  4.423544  5.172106
# ...

# %% [markdown]
# ### Create plot

# %%
plt.figure()
plt.plot('x','y','ro',data=log)
plt.axis([0, 8, 0, 8])
# Out:
# [0, 8, 0, 8]
